# %%
import pandas as pd

# %%
df = pd.read_csv('hw2_satimage.scale.training.csv')

# %%
df.shape
# Out:
# (4435, 37)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (3188, 37)

# %%
df.head(30)
# Out:
#     1           2            3             4             5             6  \
# 2   6     01:00.6      02:00.5       03:00.3  4:-0.0743802       05:00.4
# 9   6     01:00.6      02:00.5       03:00.5  4:-0.0247934       05:00.7
# 10  6     01:00.6      02:00.6       03:00.3  4:-0.0743802       05:00.5
# 13  6     01:00.6      02:00.5       03:00.5  4:-0.0247934       05:00.5
# 17  6     01:00.5      02:00.5       03:00.6  4:-0.0909091       05:00.5
# 18  6     01:00.6      02:00.5       03:00.2  4:-0.0743802       05:00.5
# 20  6     01:00.1      02:00.1   3:-0.047619    4:-0.38843       05:00.2
# 21  6     01:00.3      02:00.1   3:-0.214286   4:-0.338843  5:-0.0322581
# 22  6     01:00.4      02:00.2       03:00.0   4:-0.173554       05:00.3
# 23  6     01:00.6      02:00.6       03:00.3  4:-0.0247934       05:00.6
# 24  2    1:-0.875  2:-0.872727       03:00.7       04:00.8   5:-0.870968
# 25  1  1:-0.15625      02:00.5       03:00.5  4:-0.0247934   5:-0.129032
# ...
