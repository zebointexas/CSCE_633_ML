# %%
import os
import math
import numpy as np
import datetime as dt
from numpy import newaxis
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.figure(num=None, figsize=(20, 2))
plt.plot(x, y, '-ok');
